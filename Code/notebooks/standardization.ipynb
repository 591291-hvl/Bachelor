# %% [markdown]
# This does not work

# %%
import sys
from pathlib import Path

import os

import numpy as np

# %%
module_path = str(Path.cwd().parents[0] / "src")

if module_path not in sys.path:
    sys.path.append(module_path)

from dataloader import *
from plotCreator import *

# %%
data_path0 = str(Path.cwd().parents[0] / "data" / "bh" / "BH_n5_M8_res100_10000_events.h5")
data_path1 = str(Path.cwd().parents[0] / "data" / "sph" / "PP13-Sphaleron-THR9-FRZ15-NB0-NSUBPALL_res100_10000_events.h5")
bhArray = dataToArray(data_path0)
sphArray = dataToArray(data_path1)

# %%
# valueHistogram(bhArray[0])
standardPlot(bhArray[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
clippedBHarray = np.clip(bhArray[0],0,255)
# valueHistogram(clippedBHarray)
standardPlot(clippedBHarray)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
uint8ClippedBHarray = clippedBHarray.astype(np.uint8)
# valueHistogram(uint8ClippedBHarray)
standardPlot(uint8ClippedBHarray)
