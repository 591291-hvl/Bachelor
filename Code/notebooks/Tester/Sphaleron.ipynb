# %%
import h5py
from pathlib import Path
import os
import sys

import numpy as np
# from PIL import Image
# import cv2
from matplotlib import pyplot as plt
# import seaborn as sns

# %%
data_path = 'C:/Users/student/Desktop/ORIGINAL DATA/2dhistograms'

# %%
def get2dHistograms(path):
    #improve this function
    #todo: view difference between files
    f = h5py.File(data_path + '/sph/100/PP13-Sphaleron-THR9-FRZ15-NB0-NSUBPALL_res100_10000_events.h5')
    keys = list(f.keys())
    dataset = [f[key]["data"] for key in keys]
    
    return dataset

# %%
def valueHistogram(array):
    #this function sucks
    flattenArray = [x for x in array.flatten("C") if not x < 1.0]
    plt.hist(x=flattenArray, bins='auto')

# %%
dataset = get2dHistograms(data_path)

# %%
array = np.array(dataset)

# %%
plt.imshow(array[0], cmap='gray')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
valueHistogram(array[20])

# %%
array.sum()
# Out:
# 111558160.0

# %%
np.array([1 if x != 0.0 else 0 for x in array.flatten("C")]).mean()
# Out:
# 0.01342694
